# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\mk744\Downloads\Knowledge Box\documents\datafiles\Wine.csv")
data.shape
# Out:
# (178, 14)

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import pymysql
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:@localhost/movies")
data.to_sql('Ans', con = engine, if_exists='append', index=False)
# Out:
# 178

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", user="root", passwd="", database="movies", use_pure=True)
    
    if mydb.is_connected():
        print("Successfully connected to the movies database.")
except Exception as e:
    print("Error:", str(e))
# Out:
# Successfully connected to the movies database.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df = pd.read_sql("SELECT * FROM Ans", mydb)
df
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2665    13.71        5.65  2.45          20.5       95.0           1.68
# 2666    13.40        3.91  2.48          23.0      102.0           1.80
# 2667    13.27        4.28  2.26          20.0      120.0           1.59
# 2668    13.17        2.59  2.37          20.0      120.0           1.65
# 2669    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
Avg_Alcohol_content = pd.read_sql("SELECT AVG(Alcohol) AS Average_Alcohol_Count FROM Ans", mydb)
Avg_Alcohol_content
# Out:
#    Average_Alcohol_Count
# 0              12.991314

# %%
# Find the wines with the highest Alcohol content.
# Subquery: Select wines where alcohol is greater than the average alcohol content.
Wine = pd.read_sql("SELECT * FROM Ans WHERE Alcohol > (SELECT AVG(Alcohol) FROM Ans)", mydb)
Wine
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 1345    13.71        5.65  2.45          20.5       95.0           1.68
# 1346    13.40        3.91  2.48          23.0      102.0           1.80
# 1347    13.27        4.28  2.26          20.0      120.0           1.59
# 1348    13.17        2.59  2.37          20.0      120.0           1.65
# 1349    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# List wines with a Proline value greater than the average.
# Subquery: Compare Proline value to the average in the dataset.
Proline_Value = pd.read_sql("SELECT * FROM Ans WHERE Proline > (SELECT AVG(Proline) FROM Ans)", mydb)
Proline_Value
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       14.20        1.76  2.45          15.2      112.0           3.27
# ...       ...         ...   ...           ...        ...            ...
# 1060    12.45        3.03  2.64          27.0       97.0           1.90
# 1061    13.58        2.58  2.69          24.5      105.0           1.55
# 1062    13.40        3.91  2.48          23.0      102.0           1.80
# 1063    13.27        4.28  2.26          20.0      120.0           1.59
# 1064    13.17        2.59  2.37          20.0      120.0           1.65
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Find wines with higher Flavanoids than the wine with the lowest Malic_Acid.
# Subquery: Get the minimum Malic_Acid value and compare Flavanoids.
Minim_Malic_Acid = pd.read_sql(
    """
    SELECT * 
    FROM Ans 
    WHERE Flavanoids > (
        SELECT Flavanoids 
        FROM Ans 
        WHERE Malic_Acid = (SELECT MIN(Malic_Acid) FROM Ans)
        LIMIT 1
    )
    """, mydb
)

Minim_Malic_Acid
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 1375    11.87        4.31  2.39          21.0       82.0           2.86
# 1376    12.07        2.16  2.17          21.0       85.0           2.60
# 1377    12.43        1.53  2.29          21.5       86.0           2.74
# 1378    11.79        2.13  2.78          28.5       92.0           2.13
# 1379    12.37        1.63  2.30          24.5       88.0           2.22
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Display wines that have an Ash value higher than the average ash in the YES customer segment.
# Subquery: Filter by customer segment and get the average.
Ash_value = pd.read_sql("SELECT * FROM Ans WHERE Ash > (SELECT AVG(ASH) FROM Ans WHERE Customer_Segment='YES')", mydb)
Ash_value
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.16        2.36  2.67          18.6      101.0           2.80
# 2       14.37        1.95  2.50          16.8      113.0           3.85
# 3       13.24        2.59  2.87          21.0      118.0           2.80
# 4       14.20        1.76  2.45          15.2      112.0           3.27
# ...       ...         ...   ...           ...        ...            ...
# 1285    14.16        2.51  2.48          20.0       91.0           1.68
# 1286    13.71        5.65  2.45          20.5       95.0           1.68
# 1287    13.40        3.91  2.48          23.0      102.0           1.80
# 1288    13.17        2.59  2.37          20.0      120.0           1.65
# 1289    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Find wines where the Color_Intensity is greater than the average intensity of NO customer segment wines.
# Subquery: Average color intensity by segment.
Color_Intensity = pd.read_sql("SELECT * FROM Ans WHERE Color_Intensity > (SELECT AVG(Color_Intensity) FROM Ans WHERE Customer_Segment = 'NO')", mydb)
Color_Intensity
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.16        2.36  2.67          18.6      101.0           2.80
# 2       14.37        1.95  2.50          16.8      113.0           3.85
# 3       14.20        1.76  2.45          15.2      112.0           3.27
# 4       14.39        1.87  2.45          14.6       96.0           2.50
# ...       ...         ...   ...           ...        ...            ...
# 1165    13.71        5.65  2.45          20.5       95.0           1.68
# 1166    13.40        3.91  2.48          23.0      102.0           1.80
# 1167    13.27        4.28  2.26          20.0      120.0           1.59
# 1168    13.17        2.59  2.37          20.0      120.0           1.65
# 1169    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Select wines with Magnesium above the maximum Magnesium found in wines with below-average Alcohol.
# Subquery: Use a subquery to find maximum Magnesium where Alcohol is below the average.
Max_Magenesium = pd.read_sql("SELECT * FROM Ans WHERE Magnesium > (SELECT MAX(Magnesium) FROM Ans WHERE Alcohol < (SELECT AVG(Alcohol) FROM Ans))", mydb)
Max_Magenesium
# Out:
# Empty DataFrame
# Columns: [Alcohol, Malic_Acid, Ash, Ash_Alcanity, Magnesium, Total_Phenols, Flavanoids, Nonflavanoid_Phenols, Proanthocyanins, Color_Intensity, Hue, OD280, Proline, Customer_Segment]
# Index: []

# %%
# Select wines with Hue less than the minimum Hue value from the YES customer segment.
# Subquery: Get minimum Hue from the segment.
Min_Hue = pd.read_sql("SELECT * FROM Ans WHERE Hue >(SELECT MIN(Hue) FROM Ans WHERE Customer_Segment = 'YES')", mydb)
Min_Hue
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2620    13.71        5.65  2.45          20.5       95.0           1.68
# 2621    13.40        3.91  2.48          23.0      102.0           1.80
# 2622    13.27        4.28  2.26          20.0      120.0           1.59
# 2623    13.17        2.59  2.37          20.0      120.0           1.65
# 2624    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Select wines where Flavanoids is higher than in wines with Alcohol lower than 13.
# Subquery: Query for wines with lower alcohol.
Lower_Alcohol = pd.read_sql("SELECT * FROM Ans WHERE Flavanoids > (SELECT AVG(Flavanoids) FROM Ans WHERE Alcohol < 13)", mydb)
Lower_Alcohol
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 1510    11.87        4.31  2.39          21.0       82.0           2.86
# 1511    12.07        2.16  2.17          21.0       85.0           2.60
# 1512    12.43        1.53  2.29          21.5       86.0           2.74
# 1513    11.79        2.13  2.78          28.5       92.0           2.13
# 1514    12.37        1.63  2.30          24.5       88.0           2.22
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Find wines where Total_Phenols is above the average for the NO segment.
# Subquery: Compare to the average Total_Phenols in NO.
Phenols = pd.read_sql("SELECT * FROM Ans WHERE Total_Phenols > (SELECT AVG(Total_Phenols) FROM Ans WHERE Customer_Segment = 'NO')", mydb)
Phenols
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 1315    12.43        1.53  2.29          21.5       86.0           2.74
# 1316    12.84        2.96  2.61          24.0      101.0           2.32
# 1317    14.34        1.68  2.70          25.0       98.0           2.80
# 1318    13.48        1.67  2.64          22.5       89.0           2.60
# 1319    12.36        3.83  2.38          21.0       88.0           2.30
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# List wines with OD280 higher than the average of wines where Malic_Acid is above 2.0.
# Subquery: Calculate average for a subset of wines.
Wine_List = pd.read_sql("SELECT * FROM Ans WHERE OD280 > (SELECT AVG(OD280)FROM Ans WHERE Malic_Acid > 2.0  )", mydb)
Wine_List
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 1720    11.79        2.13  2.78          28.5       92.0           2.13
# 1721    12.37        1.63  2.30          24.5       88.0           2.22
# 1722    12.04        4.30  2.38          22.0       80.0           2.10
# 1723    12.93        2.81  2.70          21.0       96.0           1.54
# 1724    13.36        2.56  2.35          20.0       89.0           1.40
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Find wines with Malic_Acid less than the average for wines with Alcohol above 13.5.
# Subquery: Get the average Malic_Acid for wines with high alcohol content.
Less_Malic_Acid = pd.read_sql("SELECT * FROM Ans WHERE Malic_Acid > (SELECT AVG(Malic_Acid) FROM Ans WHERE Alcohol > 13.5)", mydb)
Less_Malic_Acid
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       13.16        2.36  2.67          18.6      101.0           2.80
# 1       13.24        2.59  2.87          21.0      118.0           2.80
# 2         NaN        3.10  2.56          15.2      116.0           2.70
# 3         NaN        3.80  2.65          18.6      102.0           2.41
# 4       14.22        3.99  2.51          13.2      128.0           3.00
# ...       ...         ...   ...           ...        ...            ...
# 1015    13.71        5.65  2.45          20.5       95.0           1.68
# 1016    13.40        3.91  2.48          23.0      102.0           1.80
# 1017    13.27        4.28  2.26          20.0      120.0           1.59
# 1018    13.17        2.59  2.37          20.0      120.0           1.65
# 1019    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Display wines with Proline higher than the maximum in the YES segment.
# Subquery: Find maximum Proline for YES wines.
Proline_amount = pd.read_sql("SELECT * FROM ANS WHERE Proline = (SELECT MAX(Proline) FROM Ans WHERE Customer_Segment = 'YES')", mydb)
Proline_amount
# Out:
#     Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0     14.19        1.59  2.48          16.5      108.0            3.3
# 1     14.19        1.59  2.48          16.5      108.0            3.3
# 2     14.19        1.59  2.48          16.5      108.0            3.3
# 3     14.19        1.59  2.48          16.5      108.0            3.3
# 4     14.19        1.59  2.48          16.5      108.0            3.3
# 5     14.19        1.59  2.48          16.5      108.0            3.3
# 6     14.19        1.59  2.48          16.5      108.0            3.3
# 7     14.19        1.59  2.48          16.5      108.0            3.3
# 8     14.19        1.59  2.48          16.5      108.0            3.3
# 9     14.19        1.59  2.48          16.5      108.0            3.3
# 10    14.19        1.59  2.48          16.5      108.0            3.3
# 11    14.19        1.59  2.48          16.5      108.0            3.3
# ...

# %%
# Find wines with Ash_Alcanity greater than the average in wines where Flavanoids is above 3.
# Subquery: Filter by Flavanoids.
Ash_Alcanity = pd.read_sql("SELECT * FROM Ans WHERE Ash_Alcanity > (SELECT AVG(Ash_Alcanity) FROM Ans WHERE Flavanoids > 3)", mydb)
Ash_Alcanity
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       13.16        2.36  2.67          18.6      101.0           2.80
# 1       13.24        2.59  2.87          21.0      118.0           2.80
# 2       14.06        2.15  2.61          17.6      121.0           2.60
# 3       14.10        2.16  2.30          18.0        NaN           2.95
# 4       13.63        1.81  2.70          17.2      112.0           2.85
# ...       ...         ...   ...           ...        ...            ...
# 2005    13.71        5.65  2.45          20.5       95.0           1.68
# 2006    13.40        3.91  2.48          23.0      102.0           1.80
# 2007    13.27        4.28  2.26          20.0      120.0           1.59
# 2008    13.17        2.59  2.37          20.0      120.0           1.65
# 2009    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Select wines where Color_Intensity is above the minimum of wines with Proanthocyanins greater than 2.
Colour_Intensity = pd.read_sql("SELECT * FROM Ans WHERE Color_Intensity > (SELECT MIN(Color_Intensity) FROM Ans WHERE Proanthocyanins > 2)", mydb)
Colour_Intensity
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2620    13.71        5.65  2.45          20.5       95.0           1.68
# 2621    13.40        3.91  2.48          23.0      102.0           1.80
# 2622    13.27        4.28  2.26          20.0      120.0           1.59
# 2623    13.17        2.59  2.37          20.0      120.0           1.65
# 2624    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# List wines with Hue higher than the average Hue in wines where OD280 is below 3.
# Subquery: Get the average Hue for a subset.
Hue_Max = pd.read_sql("SELECT * FROM Ans WHERE Hue > (SELECT AVG(Hue) FROM Ans WHERE OD280 < 3)" , mydb)
Hue_Max
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       13.24        2.59  2.87          21.0      118.0           2.80
# 4       14.20        1.76  2.45          15.2      112.0           3.27
# ...       ...         ...   ...           ...        ...            ...
# 1570    12.00        3.43  2.00          19.0       87.0           2.00
# 1571    11.56        2.05  3.23          28.5      119.0           3.18
# 1572    12.42        4.43  2.73          26.5      102.0           2.20
# 1573    11.79        2.13  2.78          28.5       92.0           2.13
# 1574    13.69        3.26  2.54          20.0      107.0           1.83
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Display wines where Malic_Acid is higher than the minimum in the YES segment.
# Subquery: Find minimum for the segment.
Higher_Minm = pd.read_sql("SELECT * FROM Ans WHERE Malic_Acid > (SELECT MIN(Malic_Acid) FROM Ans WHERE Customer_Segment = 'YES')", mydb)
Higher_Minm
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2635    13.71        5.65  2.45          20.5       95.0           1.68
# 2636    13.40        3.91  2.48          23.0      102.0           1.80
# 2637    13.27        4.28  2.26          20.0      120.0           1.59
# 2638    13.17        2.59  2.37          20.0      120.0           1.65
# 2639    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Select wines where Alcohol is lower than the average of wines with Magnesium above 120.
# Subquery: Query average Alcohol.
Alcohol_content = pd.read_sql("SELECT * FROM Ans WHERE Alcohol <  (SELECT AVG(Alcohol) FROM Ans WHERE Magnesium > 120)", mydb)
Alcohol_content
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       12.85        1.60  2.52          17.8       95.0           2.48
# 1       13.05        2.05  3.22          25.0      124.0           2.63
# 2       13.05        1.65  2.55          18.0       98.0           2.45
# 3       13.07        1.50  2.10          15.5       98.0           2.40
# 4       13.05        1.77  2.10          17.0      107.0           3.00
# ...       ...         ...   ...           ...        ...            ...
# 1435    12.85        3.27  2.58          22.0      106.0           1.65
# 1436    12.96        3.45  2.35          18.5      106.0           1.39
# 1437    12.82        3.37  2.30          19.5       88.0           1.48
# 1438    12.20        3.03  2.32          19.0       96.0           1.25
# 1439    12.77        2.39  2.28          19.5       86.0           1.39
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Find wines with Ash lower than the maximum for wines where Malic_Acid is below 2.
# Subquery: Find the maximum for a subset.
Ash_lower = pd.read_sql("SELECT * FROM Ans WHERE Ash < (SELECT MAX(Ash) FROM Ans WHERE Malic_Acid < 2)", mydb)
Ash_lower
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       14.20        1.76  2.45          15.2      112.0           3.27
# ...       ...         ...   ...           ...        ...            ...
# 2575    13.71        5.65  2.45          20.5       95.0           1.68
# 2576    13.40        3.91  2.48          23.0      102.0           1.80
# 2577    13.27        4.28  2.26          20.0      120.0           1.59
# 2578    13.17        2.59  2.37          20.0      120.0           1.65
# 2579    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Find wines with Proline higher than the average for wines where Color_Intensity is above 5.
# Subquery: Compare Proline.
Compare_Proline = pd.read_sql("SELECT * FROM Ans WHERE Proline > (SELECT AVG(Proline) FROM Ans WHERE Color_Intensity > 5)", mydb)
Compare_Proline
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6      127.0           2.80
# 1      13.20        1.78  2.14          11.2      100.0           2.65
# 2      13.16        2.36  2.67          18.6      101.0           2.80
# 3      14.37        1.95  2.50          16.8      113.0           3.85
# 4      14.20        1.76  2.45          15.2      112.0           3.27
# ..       ...         ...   ...           ...        ...            ...
# 745    14.22        1.70  2.30          16.3      118.0           3.20
# 746    13.29        1.97  2.68          16.8      102.0           3.00
# 747    13.72        1.43  2.50          16.7      108.0           3.40
# 748    12.99        1.67  2.60          30.0      139.0           3.30
# 749    12.47        1.52  2.20          19.0      162.0           2.50
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
# List wines where Total_Phenols is greater than the average for wines with Alcohol above 14.
# Subquery: Calculate average for Alcohol > 14.
Average_Alcohol = pd.read_sql("SELECT * FROM Ans WHERE Total_Phenols > (SELECT AVG(Total_Phenols) FROM Ans WHERE Alcohol > 14)", mydb)
Average_Alcohol
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.37        1.95  2.50          16.8      113.0           3.85
# 1      14.20        1.76  2.45          15.2      112.0           3.27
# 2      13.86        1.35  2.27          16.0        NaN           2.98
# 3      14.10        2.16  2.30          18.0        NaN           2.95
# 4      14.75        1.73  2.39          11.4       91.0           3.10
# ..       ...         ...   ...           ...        ...            ...
# 580    12.29        3.17  2.21          18.0       88.0           2.85
# 581    11.46        3.74  1.82          19.5      107.0           3.18
# 582    11.45        2.40  2.42          20.0       96.0           2.90
# 583    11.56        2.05  3.23          28.5      119.0           3.18
# 584    11.87        4.31  2.39          21.0       82.0           2.86
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
# Find wines where Ash_Alcanity is below the minimum for the NO segment.
# Subquery: Find minimum for the NO segment.
Min_Ash = pd.read_sql("SELECT * FROM Ans WHERE Ash_Alcanity < (SELECT MIN(Ash_Alcanity) FROM Ans WHERE Customer_Segment='NO')", mydb)
Min_Ash
# Out:
# Empty DataFrame
# Columns: [Alcohol, Malic_Acid, Ash, Ash_Alcanity, Magnesium, Total_Phenols, Flavanoids, Nonflavanoid_Phenols, Proanthocyanins, Color_Intensity, Hue, OD280, Proline, Customer_Segment]
# Index: []

# %%
# Select wines where Magnesium is higher than the maximum in wines with Ash below 2.4.
# Subquery: Use Ash as a filter.
Ash_Filter = pd.read_sql("SELECT * FROM Ans WHERE Magnesium < (SELECT MAX(Magnesium) FROM Ans WHERE Ash < 2.4)", mydb)
Ash_Filter
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2515    13.71        5.65  2.45          20.5       95.0           1.68
# 2516    13.40        3.91  2.48          23.0      102.0           1.80
# 2517    13.27        4.28  2.26          20.0      120.0           1.59
# 2518    13.17        2.59  2.37          20.0      120.0           1.65
# 2519    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# List wines where Alcohol is above the average of the wines with the highest Flavanoids.
# Subquery: Average Alcohol for a subset.
Avg_Alcohol = pd.read_sql("SELECT * FROM Ans WHERE Alcohol > (SELECT AVG(Alcohol) FROM Ans WHERE Flavanoids IN (SELECT MAX(Flavanoids) FROM Ans))", mydb)
Avg_Alcohol
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2545    13.71        5.65  2.45          20.5       95.0           1.68
# 2546    13.40        3.91  2.48          23.0      102.0           1.80
# 2547    13.27        4.28  2.26          20.0      120.0           1.59
# 2548    13.17        2.59  2.37          20.0      120.0           1.65
# 2549    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Display wines where Proanthocyanins is above the minimum of wines with OD280 less than 3.
# Subquery: Compare with the minimum OD280 subset.
OD280_subset = pd.read_sql("SELECT * FROM Ans WHERE Proanthocyanins > (SELECT MIN(Proanthocyanins) FROM Ans WHERE OD280 < 3)", mydb)
OD280_subset
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2410    13.71        5.65  2.45          20.5       95.0           1.68
# 2411    13.40        3.91  2.48          23.0      102.0           1.80
# 2412    13.27        4.28  2.26          20.0      120.0           1.59
# 2413    13.17        2.59  2.37          20.0      120.0           1.65
# 2414    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Find wines where Flavanoids is higher than the average for wines with Proline above 1000.
# Subquery: Compare Flavanoids for a specific range.
Compare_Flavanoids = pd.read_sql("SELECT * FROM Ans WHERE Flavanoids > (SELECT AVG(Flavanoids) FROM Ans WHERE Proline > 1000)" , mydb)
Compare_Flavanoids
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6      127.0           2.80
# 1      13.16        2.36  2.67          18.6      101.0           2.80
# 2      14.37        1.95  2.50          16.8      113.0           3.85
# 3      14.20        1.76  2.45          15.2      112.0           3.27
# 4      13.86        1.35  2.27          16.0        NaN           2.98
# ..       ...         ...   ...           ...        ...            ...
# 460    12.37        1.07  2.10          18.5       88.0           3.52
# 461    12.29        3.17  2.21          18.0       88.0           2.85
# 462    11.56        2.05  3.23          28.5      119.0           3.18
# 463    11.87        4.31  2.39          21.0       82.0           2.86
# 464    12.43        1.53  2.29          21.5       86.0           2.74
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
# Select wines where Alcohol is lower than the maximum Alcohol found in wines with Ash_Alcanity above 15.
# Subquery: Find maximum for a subset.
Max_Alcohol = pd.read_sql("SELECT * FROM Ans WHERE Alcohol < (SELECT MAX(Alcohol) FROM Ans WHERE Ash_Alcanity > 15)", mydb)
Max_Alcohol
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2545    13.71        5.65  2.45          20.5       95.0           1.68
# 2546    13.40        3.91  2.48          23.0      102.0           1.80
# 2547    13.27        4.28  2.26          20.0      120.0           1.59
# 2548    13.17        2.59  2.37          20.0      120.0           1.65
# 2549    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# List wines where Total_Phenols is higher than the minimum for wines with Magnesium below 110.
# Subquery: Query the minimum.
Query_min = pd.read_sql("SELECT * FROM Ans WHERE Total_Phenols > (SELECT MIN(Total_Phenols) FROM Ans WHERE Magnesium < 110)", mydb)
Query_min
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2530    13.71        5.65  2.45          20.5       95.0           1.68
# 2531    13.40        3.91  2.48          23.0      102.0           1.80
# 2532    13.27        4.28  2.26          20.0      120.0           1.59
# 2533    13.17        2.59  2.37          20.0      120.0           1.65
# 2534    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Display wines with OD280 greater than the average OD280 for wines where Alcohol is less than 13.
# Subquery: Calculate average OD280.
Display_wine = pd.read_sql("SELECT * FROM Ans WHERE OD280 > (SELECT AVG(OD280) FROM Ans WHERE Alcohol < 13)", mydb)
Display_wine
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 1525    11.87        4.31  2.39          21.0       82.0           2.86
# 1526    12.07        2.16  2.17          21.0       85.0           2.60
# 1527    12.43        1.53  2.29          21.5       86.0           2.74
# 1528    12.37        1.63  2.30          24.5       88.0           2.22
# 1529    12.04        4.30  2.38          22.0       80.0           2.10
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Find wines with Hue less than the maximum Hue found in wines with Proline greater than 1000.
# Subquery: Compare Hue.
Hue_Less = pd.read_sql("SELECT * FROM Ans WHERE Hue < (SELECT MAX(Hue) FROM Ans WHERE Proline > 1000)", mydb)
Hue_Less
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       13.16        2.36  2.67          18.6      101.0           2.80
# 3       14.37        1.95  2.50          16.8      113.0           3.85
# 4       13.24        2.59  2.87          21.0      118.0           2.80
# ...       ...         ...   ...           ...        ...            ...
# 2500    13.71        5.65  2.45          20.5       95.0           1.68
# 2501    13.40        3.91  2.48          23.0      102.0           1.80
# 2502    13.27        4.28  2.26          20.0      120.0           1.59
# 2503    13.17        2.59  2.37          20.0      120.0           1.65
# 2504    14.13        4.10  2.74          24.5       96.0           2.05
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...

# %%
# Select wines where Ash is lower than the average for wines with Alcohol above 14.
# Subquery: Get average Ash.
Avg_Ash = pd.read_sql("SELECT * FROM Ans WHERE Ash < (SELECT AVG(Ash) FROM Ans WHERE Alcohol > 14)", mydb)
Avg_Ash
# Out:
#       Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0       14.23        1.71  2.43          15.6      127.0           2.80
# 1       13.20        1.78  2.14          11.2      100.0           2.65
# 2       14.83        1.64  2.17          14.0        NaN           2.80
# 3       13.86        1.35  2.27          16.0        NaN           2.98
# 4       14.10        2.16  2.30          18.0        NaN           2.95
# ...       ...         ...   ...           ...        ...            ...
# 1660    12.82        3.37  2.30          19.5       88.0           1.48
# 1661    12.20        3.03  2.32          19.0       96.0           1.25
# 1662    12.77        2.39  2.28          19.5       86.0           1.39
# 1663    13.27        4.28  2.26          20.0      120.0           1.59
# 1664    13.17        2.59  2.37          20.0      120.0           1.65
#
#       Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# ...
