# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\mk744\OneDrive - Poornima University\Desktop\Customer_Analytics.csv")

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import pymysql
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:@localhost/movies")
data.to_sql('Dataset', con = engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File c:\Users\mk744\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1807     if not evt_handled:
# -> 1808         self.dialect.do_execute(
#    1809             cursor, statement, parameters, context
#    1810         )
#    1812 if self._has_events or self.engine._has_events:
#
# File c:\Users\mk744\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File c:\Users\mk744\anaconda3\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
# ...

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", user="root", passwd="", database="movies", use_pure=True)
    
    if mydb.is_connected():
        print("Successfully connected to the movies database.")
except Exception as e:
    print("Error:", str(e))
# Out:
# Successfully connected to the movies database.

# %%
df = pd.read_sql("SELECT * FROM sampledata LIMIT 5", mydb)
df
# Out:
#    Row_Id        Order_Id  Order_Date   Ship_Date       Ship_Mode Customer_Id  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_Id         Category Sub_Category  \
# ...

# %%
df.columns.tolist()
# Out:
# ['Customer_Id', 'Sum_of_sales_amount']

# %% [markdown]
# # Find customers who placed orders in 2023:

# %%
Customer_palced_order = pd.read_sql("SELECT Customer_Name FROM sampledata WHERE Customer_Id IN (SELECT Customer_Id FROM sampledata WHERE YEAR(Order_Date) = 2023)", mydb)
# Out:
# Empty DataFrame
# Columns: [Customer_Name]
# Index: []

# %%
ans = pd.read_sql("SHOW DATABASES", mydb)
ans
# Out:
#               Database
# 0         admitad_data
# 1              campusx
# 2         company_data
# 3          cuelinks_fs
# 4            data_july
# 5            data_june
# 6                 demo
# 7               gender
# 8   information_schema
# 9                  ipl
# 10           july_data
# 11           june_data
# 12                khan
# 13              movies
# 14               mysql
# 15  performance_schema
# 16          phpmyadmin
# 17              result
# 18            treadmil
# 19        work_details
# 20               world
# 21              zomato

# %% [markdown]
# # Get the total sales amount of each customer:

# %%
df = pd.read_sql("SELECT Customer_Id, SUM(Sales) AS Sum_of_sales_amount FROM sampledata WHERE Customer_Id IN(SELECT Customer_Id FROM sampledata) GROUP BY Customer_Id", mydb)
df
# Out:
#     Customer_Id  Sum_of_sales_amount
# 0      AA-10315            22254.240
# 1      AA-10375             4225.560
# 2      AA-10480             7162.048
# 3      AA-10645            20347.740
# 4      AB-10015             3544.624
# ..          ...                  ...
# 788    XP-21865             9498.632
# 789    YC-21895            21817.400
# 790    YS-21880            26881.776
# 791    ZC-21910            32102.828
# 792    ZD-21925             5975.776
#
# [793 rows x 2 columns]

# %% [markdown]
# # Find all products that were ordered more than once:

# %%
data = pd.read_sql("Select * from sampledata Limit 2", mydb)
data.columns.tolist()
# Out:
# ['Row_Id',
#  'Order_Id',
#  'Order_Date',
#  'Ship_Date',
#  'Ship_Mode',
#  'Customer_Id',
#  'Customer_Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal_Code',
#  'Region',
#  'Product_Id',
#  'Category',
#  'Sub_Category',
#  'Product_Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Price']
